# %%
import numpy
marks=numpy.array([50,80,20,10])
hours=numpy.array([5,8,2,1])
import matplotlib.pyplot as plot  #used to plot graph from data
#linear graph is known as scatter graph
plot.scatter(hours,marks)

# %%
plot.plot(marks,hours) #1st plot is the name of my variable. 2nd plot is the function.
